# %% [markdown]
# # Propensity to Pay — Full Pipeline
# Run each cell in order: Clean → Preprocess → Model

# %% [markdown]
# ## Step 1: Clean Data

# %%
# %run src/cleaning.py

# %%
# Verify cleaned data
import pandas as pd

df_cleaned = pd.read_csv('data/processed/cleaned_data.csv')
print(f'Shape: {df_cleaned.shape}')
print(f'Nulls: {df_cleaned.isnull().sum().sum()}')
df_cleaned.head()

# %% [markdown]
# ## Step 2: Preprocess Data

# %%
# %run src/preprocessing.py

# %%
# Verify preprocessed data
import pickle

with open('data/processed/preprocessed_data.pkl', 'rb') as f:
    data = pickle.load(f)

print(f"X_train: {data['X_train'].shape}")
print(f"X_test:  {data['X_test'].shape}")
print(f"Features: {data['feature_names']}")

# %% [markdown]
# ## Step 3: Train & Evaluate Models

# %%
# %run src/modeling.py

# %%
# Final comparison table
print(comparison)
